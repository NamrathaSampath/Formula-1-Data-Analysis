# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
sns.set()

# %%
df_circuits = pd.read_csv(r'circuits.csv')
df_circuits.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya     MontmelÌ_
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng
# 0  Australia -37.84970  144.96800
# 1   Malaysia   2.76083  101.73800
# 2    Bahrain  26.03250   50.51060
# 3      Spain  41.57000    2.26111
# 4     Turkey  40.95170   29.40500

# %%
print(df_circuits.isnull().sum())
# Out:
# circuitId     0
# circuitRef    0
# name          0
# location      0
# country       0
# lat           0
# lng           0
# dtype: int64

# %%
print(df_circuits.duplicated().sum())
# Out:
# 0

# %%
df_constructorResults = pd.read_csv(r'constructorResults.csv')
df_constructorResults.head()
# Out:
#    constructorResultsId  raceId  constructorId  points status  wins
# 0                     1      18              1    14.0    NaN     1
# 1                     2      18              2     8.0    NaN     0
# 2                     3      18              3     9.0    NaN     0
# 3                     4      18              4     5.0    NaN     0
# 4                     5      18              5     2.0    NaN     0

# %%
print(df_constructorResults.isnull().sum())
# Out:
# constructorResultsId        0
# raceId                      0
# constructorId               0
# points                      0
# status                  11125
# wins                        0
# dtype: int64

# %% [markdown]
# status is kept as nan (NULL) for all non-disqualified constructors. Which is why we see a lot of NULL values that are retained as is. The status is 'D' for disqualified teams.

# %%
print(df_constructorResults.duplicated().sum())
# Out:
# 0

# %%
df_constructors = pd.read_csv(r'constructors.csv')
df_constructors.head()
# Out:
#    constructorId constructorRef        name nationality
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian

# %%
print(df_constructors.isnull().sum())
# Out:
# constructorId     0
# constructorRef    0
# name              0
# nationality       0
# dtype: int64

# %%
print(df_constructors.duplicated().sum())
# Out:
# 0

# %%
df_drivers = pd.read_csv(r'drivers.csv')
df_drivers.head()
# Out:
#    driverId   driverRef  number code  forename     surname         dob  \
# 0         1    hamilton    44.0  HAM     Lewis    Hamilton    7/1/1985
# 1         2    heidfeld     NaN  HEI      Nick    Heidfeld   10/5/1977
# 2         3     rosberg     6.0  ROS      Nico     Rosberg  27-06-1985
# 3         4      alonso    14.0  ALO  Fernando      Alonso  29-07-1981
# 4         5  kovalainen     NaN  KOV    Heikki  Kovalainen  19-10-1981
#
#   nationality Age
# 0     British  38
# 1      German  46
# 2      German  38
# 3     Spanish  42
# 4     Finnish  42

# %%
print(df_drivers.isnull().sum())
# Out:
# driverId         0
# driverRef        0
# number         804
# code             0
# forename         0
# surname          0
# dob              1
# nationality      0
# Age              0
# dtype: int64

# %% [markdown]
# drivers numbers were not given out in the biginning of the game era.

# %%
print(df_drivers.duplicated().sum())
# Out:
# 0

# %%
df_driverStandings = pd.read_csv(r'driverStandings.csv')
df_driverStandings.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
print(df_driverStandings.isnull().sum())
# Out:
# driverStandingsId    0
# raceId               0
# driverId             0
# points               0
# position             0
# positionText         0
# wins                 0
# dtype: int64

# %%
print(df_drivers.duplicated().sum())
# Out:
# 0

# %%
df_lapTimes = pd.read_csv (r'lapTimes.csv')
df_lapTimes.head()
# Out:
#    lapId  raceId  driverId  no_lap  position  time_secs  milliseconds  \
# 0      1     841        20       1         1      98.11         98109
# 1      2     841        20       2         1      93.01         93006
# 2      3     841        20       3         1      92.71         92713
# 3      4     841        20       4         1      92.80         92803
# 4      5     841        20       5         1      92.34         92342
#
#    circuitID  Year
# 0          1  2011
# 1          1  2011
# 2          1  2011
# 3          1  2011
# 4          1  2011

# %%
print(df_lapTimes.isnull().sum())
# Out:
# lapId           0
# raceId          0
# driverId        0
# no_lap          0
# position        0
# time_secs       0
# milliseconds    0
# circuitID       0
# Year            0
# dtype: int64

# %%
print(df_lapTimes.duplicated().sum())
# Out:
# 0

# %%
df_pitStops = pd.read_csv(r'pitStops.csv')
df_pitStops.head()
# Out:
#    pitstopID  raceId  driverId  stop_no  lap  lapId time_stamp  pitstop_secs  \
# 0          1     841       153        1    1   1008   17:05:23          4.72
# 1          2     841        30        1    1   1065   17:05:52          2.84
# 2          3     841        17        1   11    127   17:20:48          1.86
# 3          4     841         4        1   12    440   17:22:34          2.04
# 4          5     841        13        1   13    245   17:24:10          2.02
#
#    pitstops_milli  Pitlane_secs  pitlane_milli  round(pitlane)
# 0            4718         26.90          26898              27
# 1            2841         25.02          25021              25
# 2            1863         23.43          23426              23
# 3            2044         23.25          23251              23
# 4            2023         23.84          23842              24

# %%
print(df_pitStops.isnull().sum())
# Out:
# pitstopID         0
# raceId            0
# driverId          0
# stop_no           0
# lap               0
# lapId             0
# time_stamp        0
# pitstop_secs      0
# pitstops_milli    0
# Pitlane_secs      0
# pitlane_milli     0
# round(pitlane)    0
# dtype: int64

# %%
print(df_pitStops.duplicated().sum())
# Out:
# 0

# %%
df_qualifying = pd.read_csv(r'qualifying.csv')
df_qualifying.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position       q1  \
# 0          1      18         1              1      22         1  01:26.6
# 1          2      18         9              2       4         2  01:26.1
# 2          3      18         5              1      23         3  01:25.7
# 3          4      18        13              6       2         4  01:26.0
# 4          5      18         2              2       3         5  01:26.0
#
#         q2       q3
# 0  01:25.2  01:26.7
# 1  01:25.3  01:26.9
# 2  01:25.5  01:27.1
# 3  01:25.7  01:27.2
# 4  01:25.5  01:27.2

# %%
print(df_qualifying.isnull().sum())
# Out:
# qualifyId           0
# raceId              0
# driverId            0
# constructorId       0
# number              0
# position            0
# q1                119
# q2               3864
# q3               5338
# dtype: int64

# %% [markdown]
# q1,q2,q3 have null values that represents that means that drivers is not qualified for that qualifying round. since qualifying is held in stages and not all drivers participate

# %%
print(df_qualifying.duplicated().sum())
# Out:
# 0

# %%
df_races = pd.read_csv(r'races.csv')
df_races.head()
# Out:
#    raceId  year  round  circuitId    Country       lat        lng  \
# 0       1  2009      1          1  Australia -37.84970  144.96800
# 1       2  2009      2          2   Malaysia   2.76083  101.73800
# 2       3  2009      3         17      China  31.33890  121.22000
# 3       4  2009      4          3    Bahrain  26.03250   50.51060
# 4       5  2009      5          4      Spain  41.57000    2.26111
#
#                     name       date      time
# 0  Australian Grand Prix  3/29/2009   6:00:00
# 1   Malaysian Grand Prix   4/5/2009   9:00:00
# 2     Chinese Grand Prix  4/19/2009   7:00:00
# 3     Bahrain Grand Prix  4/26/2009  12:00:00
# 4     Spanish Grand Prix  5/10/2009  12:00:00

# %%
print(df_races.isnull().sum())
# Out:
# raceId       0
# year         0
# round        0
# circuitId    0
# Country      0
# lat          0
# lng          0
# name         0
# date         0
# time         0
# dtype: int64

# %%
print(df_races.duplicated().sum())
# Out:
# 0

# %%
df_results = pd.read_csv(r'results.csv')
df_results.head()
# Out:
#    resultId  raceId  driverId  constructorId  car_number  start_grid  \
# 0         1      18         1              1        22.0           1
# 1         2      18         2              2         3.0           5
# 2         3      18         3              3         7.0           7
# 3         4      18         4              4         5.0          11
# 4         5      18         5              1        23.0           3
#
#    position positionText  positionOrder  points  laps     time  milliseconds  \
# 0       1.0            1              1    10.0    58  34:50.6     5690616.0
# 1       2.0            2              2     8.0    58    5.478     5696094.0
# 2       3.0            3              3     6.0    58    8.163     5698779.0
# 3       4.0            4              4     5.0    58   17.181     5707797.0
# 4       5.0            5              5     4.0    58   18.014     5708630.0
#
#    fastestLap  rank fastestLapTime  fastestLap_Sec fastestLap_speed  statusId
# ...

# %%
print(df_results.duplicated().sum())
# Out:
# 0

# %%
df_results.drop('time', axis=1, inplace=True)
df_results.head()
# Out:
#    resultId  raceId  driverId  constructorId  car_number  start_grid  \
# 0         1      18         1              1        22.0           1
# 1         2      18         2              2         3.0           5
# 2         3      18         3              3         7.0           7
# 3         4      18         4              4         5.0          11
# 4         5      18         5              1        23.0           3
#
#    position positionText  positionOrder  points  laps  milliseconds  \
# 0       1.0            1              1    10.0    58     5690616.0
# 1       2.0            2              2     8.0    58     5696094.0
# 2       3.0            3              3     6.0    58     5698779.0
# 3       4.0            4              4     5.0    58     5707797.0
# 4       5.0            5              5     4.0    58     5708630.0
#
#    fastestLap  rank fastestLapTime  fastestLap_Sec fastestLap_speed  statusId
# ...

# %%
df_results.drop('fastestLapTime', axis=1, inplace=True)
df_results.head()
# Out:
#    resultId  raceId  driverId  constructorId  car_number  start_grid  \
# 0         1      18         1              1        22.0           1
# 1         2      18         2              2         3.0           5
# 2         3      18         3              3         7.0           7
# 3         4      18         4              4         5.0          11
# 4         5      18         5              1        23.0           3
#
#    position positionText  positionOrder  points  laps  milliseconds  \
# 0       1.0            1              1    10.0    58     5690616.0
# 1       2.0            2              2     8.0    58     5696094.0
# 2       3.0            3              3     6.0    58     5698779.0
# 3       4.0            4              4     5.0    58     5707797.0
# 4       5.0            5              5     4.0    58     5708630.0
#
#    fastestLap  rank  fastestLap_Sec fastestLap_speed  statusId
# 0        39.0   2.0            87.0            218.3         1
# ...

# %%
df_results.to_csv('cleaned_results_final.csv', index=False)

# %%
df_status = pd.read_csv(r'status.csv')
df_status.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
print(df_status.isnull().sum())
# Out:
# statusId    0
# status      0
# dtype: int64

# %%
print(df_status.duplicated().sum())
# Out:
# 0

# %%
print(df_combined_for_correlation.duplicated().sum())
# Out:
# 0
